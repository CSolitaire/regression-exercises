# %% [markdown]
# # Explore Continued(Mall Data)
# - using functions on new data set

# %%
from wrangle import wrangle_telco
from acquire import get_mall_data
from sklearn.model_selection import train_test_split

import explore
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
df = get_mall_data(cached=False)

# %%
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
df.describe()
# Out:
#        customer_id         age  annual_income  spending_score
# count   200.000000  200.000000     200.000000      200.000000
# mean    100.500000   38.850000      60.560000       50.200000
# std      57.879185   13.969007      26.264721       25.823522
# min       1.000000   18.000000      15.000000        1.000000
# 25%      50.750000   28.750000      41.500000       34.750000
# 50%     100.500000   36.000000      61.500000       50.000000
# 75%     150.250000   49.000000      78.000000       73.000000
# max     200.000000   70.000000     137.000000       99.000000

# %%
train_validate, test = train_test_split(df, test_size = .2, random_state = 123)
train, validate = train_test_split(train_validate, test_size = .3, random_state = 123)
train.head()
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 123          124    Male   39             69              91
# 76            77  Female   45             54              53
# 171          172    Male   28             87              75
# 10            11    Male   67             19              14
# 35            36  Female   21             33              81

# %%
explore.plot_variable_pairs(df)

# %%
explore.plot_categorical_and_continuous_vars(df,'gender', 'spending_score')

# %%
pd.cut(df.age, bins=[18, 22, 30, 40, 50, 60, 75], labels=['<21', '20s', '30s', '40s', '50s', '60+']).value_counts()
# Out:
# 30s    60
# 40s    38
# 20s    37
# 50s    23
# <21    21
# 60+    17
# Name: age, dtype: int64

# %%
df['age_cat'] = pd.cut(df.age, bins=[18, 22, 30, 40, 50, 60, 75], labels=['<21', '20s', '30s', '40s', '50s', '60+'])
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score age_cat
# 0            1    Male   19             15              39     <21
# 1            2    Male   21             15              81     <21
# 2            3  Female   20             16               6     <21
# 3            4  Female   23             16              77     20s
# 4            5  Female   31             17              40     30s

# %%
explore.plot_categorical_and_continuous_vars(df, 'age_cat', 'spending_score')
